# %%
def ult_2_dig(num):
  ult_2_dig = num % 100
  return(ult_2_dig)
num=int(input("Ingrese el numero:"))
print("Loa ultimos dos digitos son:",ult_2_dig(num))
# Out:
# Ingrese el numero:525
# Loa ultimos dosdigitos son: 25
