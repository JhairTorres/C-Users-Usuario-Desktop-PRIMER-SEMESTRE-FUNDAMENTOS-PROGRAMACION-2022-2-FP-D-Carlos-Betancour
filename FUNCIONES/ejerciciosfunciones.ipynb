# %%
#Ejercicio 1-6

# %%
#1
def ult_dig(Num):
  
  Ultimo_digito= Num %10
  return(Ultimo_digito)

Num=int(input("Ingrese un numero:  "))
print("El Ultimo digito del numero es: ", ult_dig(Num))

# %%
#2
def ult_dig(Num):
  
  Ultimo_digito= Num %100
  return(Ultimo_digito)

Num=int(input("Ingrese un numero:  "))
print("Los dos ultimos digitos son: ", ult_dig(Num))

# %%
#3
def cant_dig(Num):
  Cantidad_digito=0

  #Condicional para que solo acepte valores enteros positivos 

  while Num>=1:
    Num=Num//10
    Cantidad_digito +=1
    #Fin del ciclo while 
  return(Cantidad_digito)

Num=int(input('Ingrese un numero:  '))
print('La cantidad de digitos que tiene el numero que ingreso es:  ',cant_dig(Num))

# %%
#4
def cant_digpares(Num):
  digits=str(Num)
  count=0

  for i in range(len(digits)):
    if (int(digits[i]) % 2 == 0):
      count += 1

# %%
#5
def cant_digprimos(Num):
  digits=str(Num)
  Cuenta_Dig=0

  for i in range(len(digits)):
    if (int(digits[i]) % 10 == 2) or (int(digits[i]) % 10 == 5) or (int(digits[i]) % 10 == 7) or (int(digits[i]) % 10 == 3):
      Cuenta_Dig=Cuenta_Dig+1

  return Cuenta_Dig


Num=int(input("Ingrese un numero: "))
print("La cantidad de digitos primos es",cant_digprimos(Num))

# %%
#Ejercicios 6-10

# %%
#6
def Entero_ASCii(Num):
  digits=str(Num)
  Caracter_ASCii=[]

  for i in digits:
    Caracter_ASCii.append(ord(i))
  return Caracter_ASCii

Num=int(input("Ingrese un numero: "))
print("El entero en codigo ASCii es: ",Entero_ASCii(Num))

# %%
#7

# %%
#8
def fibonacci(n):
    a = 0
    b = 1 
    if n >=30:
        print("Incorrect input")
    elif n == 0:
        return a
    elif n == 1:
        return b
    else:
        for i in range(3,n+1):
            f.append(f[i-1] + f[i-2])
            f = a + b
            a = b
            b = f
        return b
n=input("Ingrese el número: ")
print("El número fibonacci es: ",fibonacci(n))
# Out:
# Ingrese el número: 15
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-b4f9691cbbcd> in <module>
#      17         return b
#      18 n=input("Ingrese el número: ")
# ---> 19 print("El número fibonacci es: ",fibonacci(n))
#
# <ipython-input-4-b4f9691cbbcd> in fibonacci(n)
#       3     a = 0
#       4     b = 1
# ----> 5     if n >=30:
#       6         print("Incorrect input")
#       7     elif n == 0:
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %%
#9
def factorial(n): 
    return 1 if (n==1 or n==0) else n * factorial(n - 1);  
  
num =int(input("Ingrese el número: ")) 
print("Factorial of",num,"is", factorial(num))

# %%
#10
def primer_dig(num):
  if num<=99:
    num//= 10
  elif num<=999:
    num//=100
  elif num<=9999:
    num//=1000
  elif num<=99999:
    num//=10000
  elif num<=999999:
    num//=100000
  elif num<=9999999:
    num//=1000000

  return(num)

 
num=int(input("Ingrese el digito: "))
print("El primer digito es: ",primer_dig(num))
# Out:
# Ingrese el digito: 78
# El primer digito es:  7

# %%
#Ejercicios 11-15

# %%
#11
def multiplo(a,b):
  return True if a % b == 0 else False 
a=int(input("Ingrese el valor del numero..:"))
b=int(input("Ingrese el valor del digito..:"))
print(multiplo(a,b))

# %%
#12
def DigEnNum(a,b):
  while a>=0:
        return True if a % 10 == b  else False        
a=int(input("Ingrese el valor del numero..:"))
b=int(input("Ingrese el valor del digito..:"))
entero=0
print(DigEnNum(a,b))

# %%
#13
def cont(num,dig):
  contador=0
  if num>=0:
   if num %10 == dig:
      contador=contador+1
  num//=10
  return contador
num=int(input("Ingrese el valor del numero..:"))
dig=int(input("Ingrese el valor del digito..:"))
print("cantidad de veces que esta el digito..:",cont(num,dig))

# %%
#14
def num(num1,num2):
  if num1>num2:
    return num1
  else:
    return num2
num1=int(input("Ingrese el valor del numero 1..:"))
num2=int(input("Ingrese el valor del numero 2..:"))
print(num(num1,num2)

# %%
#15
def multiplo(num1,num2):
  if num1 % num2 == 0:
    return True
  else:
      return False
num1=int(input("Ingrese el valor del numero..:"))
num2=int(input("Ingrese el valor del numero..:"))
entero=0
print(multiplo(num1,num2))

# %%
#Ejercicio 21-25

# %%
#21
def primDif_ultDig(num):
  prim_Dig=0
  ult_dig=0
  ult_dig=num%10
  if num>10:
    num//=10
  prim_Dig=num
  if ult_dig==prim_Dig:
    return(1)
  else:
    return(0)
num=int(input("Ingrese el digito: "))
print("El valor es: ",primDif_ultDig(num))
# Out:
# Ingrese el digito: 45
# El valor es:  0

# %%
#22
def mult_de_5(num):
  if (num%5==0):
    return(1)
  else:
    return(0)
num=int(input("Ingrese el digito:"))
print("El valor es:",mult_de_5(num))
# Out:
# Ingrese el digito:42
# El valor es: 0

# %%
#23
def dif_num_pri(num1,num2):
  aux=0
  dif=0
  dif=num1-num2
  contador=1
  for aux in range(1,dif,1):
    if dif % aux == 0:
      contador=contador+1
  if contador==2:
    return(1)
  else:
    return(0)
num1=int(input("Ingrese el primer digito: "))
num2=int(input("Ingrese el segundo digito: "))
print("El valor es: ",dif_num_pri(num1,num2))
# Out:
# Ingrese el primer digito: 40
# Ingrese el segundo digito: 4
# El valor es:  0

# %%
#24
def num_inversos(num1,num2):
  dig11=num1//10
  dig12=num1%10

  dig21=num2//10
  dig22=num2%10
  if dig11==dig22 and dig12==dig21:
    return(1)
  else:
    return(0)
num1=int(input("El primer numero es: "))
num2=int(input("El segundo numero es: "))
print("El valor es: ", num_inversos(num1,num2))
# Out:
# El primer numero es: 75
# El segundo numero es: 40
# El valor es:  0

# %%
#25
def pos_dig(num,dig):
  contador=0
  nDig=0
  if (num > 0 and contador<=dig-1):
    num//=10
    contador=contador+1
  nDig=num % 10
  return(nDig)
num=int(input("Ingrese el numero: "))
dig=int(input("Ingrese el digito: "))
print("El digito es: ",pos_dig(num,dig))
# Out:
# Ingrese el numero: 758
# Ingrese el digito: 1
# El digito es:  5
