# %%
suma=0
i=int (input('Ingrese'))
for i in range(3):
  resultado=2**i
  suma=suma+resultado
  i+=1
  print(resultado)
print("la suma de todo es",suma)
# Out:
# 2
# 6
# 12
# 20
# 30
# la suma de todo es 70
