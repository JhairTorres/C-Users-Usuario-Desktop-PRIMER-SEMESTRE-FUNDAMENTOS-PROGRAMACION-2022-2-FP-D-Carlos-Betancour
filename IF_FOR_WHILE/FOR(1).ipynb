# %%
inicio = int(input("Inicio :"))
fin = int(input('Fin :'))
incremento = int(input('Incremento :'))

for i in range(inicio,fin,incremento):
    print(i)
# Out:
# Inicio :5
# Fin :50
# Incremento :5
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
