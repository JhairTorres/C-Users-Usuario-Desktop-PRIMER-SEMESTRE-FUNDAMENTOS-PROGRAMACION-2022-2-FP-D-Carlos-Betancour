# %%
class Coche():
  #atributos
  ruedas=4
  cilindraje=1000
  combustible= "Gasolina"
  puerta = 3

  #metodo
  def dezplazamiento(self):
    print("El coche se esta dezplazando sobre 4 ruedas")
#Programa principal

#General instancia
#Declarar un objeto
miVehiculo=Coche()
obj_miCarro = Coche()
#acceso al atributo
print('Mi coche tiene',miVehiculo.ruedas,'ruedas')
print('Mi carrito tiene',obj_miCarro.ruedas,'ruedas')
print('Mi coche tiene',miVehiculo.combustible,'de combustible')
print('Mi carrito tiene',obj_miCarro.combustible,'de combustible')
print('Mi coche tiene',miVehiculo.cilindraje,'de cilindraje')
print('Mi coche tiene',miVehiculo.puerta,'puertas')

miVehiculo.dezplazamiento()
obj_miCarro.dezplazamiento()
# Out:
# Mi coche tiene 4 ruedas
# Mi carrito tiene 4 ruedas
# Mi coche tiene Gasolina de combustible
# Mi carrito tiene Gasolina de combustible
# Mi coche tiene 1000 de cilindraje
# Mi coche tiene 3 puertas
# El coche se esta dezplazando sobre 4 ruedas
# El coche se esta dezplazando sobre 4 ruedas

# %%
class Coche():
  ruedas=4
  def dezplazamiento(self):
    print("El coche se esta dezplazando sobre 4 ruedas")
class Moto():
   ruedas=2
   def dezplazamiento(self):
    print("La moto se esta dezplazando sobre 2 ruedas")

miCarro=Coche()
print("Primer objeto carro")
print("Mi coche tiene",miCarro.ruedas,"ruedas")
miCarro.dezplazamiento()

miMoto=Moto()
print("Mi moto tiene",miMoto.ruedas,"ruedas")
miMoto.dezplazamiento()
# Out:
# Primer objeto carro
# Mi coche tiene 4 ruedas
# El coche se esta dezplazando sobre 4 ruedas
# Mi moto tiene 2 ruedas
# La moto se esta dezplazando sobre 2 ruedas

# %%
#Costructor
class Cachorro():
  #Metodo constructor
  def __init__(self,p_color,p_raza,p_nombre):
    self.color = p_color
    self.raza = p_raza
    self.nombre = p_nombre

perrito = Cachorro("Marron claro","Golden retriver","Lukas")
obj_perritodeVicky = Cachorro("Blanco","Shitzu","fifi")
obj_perritoelBryan = Cachorro("Negro","Sin identificar","garoso")
obj_gatoValeria = Cachorro("Blanco","Angora","Late")

print("Este es el Gato-Perro de Valeria y la raza {} y es de color {} y su nombre es {}".format(obj_gatoValeria.raza,obj_gatoValeria.color,obj_gatoValeria.nombre))
print("Este es un cachorro sin dueño y la raza {} y es de color {} y su nombre es {}".format(perrito.raza,perrito.color,perrito.nombre))
print("Este es el perro de Vicky y la raza {} y es de color {} y su nombre es {}".format(obj_perritodeVicky.raza,obj_perritodeVicky.color,obj_perritodeVicky.nombre))
print("Este es el perro de bryan y la raza {} y es de color {} y su nombre es {}".format(obj_perritoelBryan.raza,obj_perritoelBryan.color,obj_perritoelBryan.nombre))
# Out:
# Este es el Gato-Perro de Valeria y la raza Angora y es de color Blanco y su nombre es Late
# Este es un cachorro sin dueño y la raza Golden retriver y es de color Marron claro y su nombre es Lukas
# Este es el perro de Vicky y la raza Shitzu y es de color Blanco y su nombre es fifi
# Este es el perro de bryan y la raza Sin identificar y es de color Negro y su nombre es garoso

# %%
class Cachorro():
  #Metodo constructor
  def __init__(self,p_color,p_raza,p_nombre):
    self.color = p_color
    self.raza = p_raza
    self.nombre = p_nombre

#Modulo
p_color = input("Color : ")
p_raza = input("Raza : ")
p_nombre = input("Nombre : ")

perrito = Cachorro(p_color,p_raza,p_nombre)
print("Este es un cachorro sin Dueño y la raza {} y es de color {} y su nombre es {}".format(perrito.raza,perrito.color,perrito.nombre))
# Out:
# Color : PURPURA
# Raza : DOBERMAN
# Nombre : FIRULAIS
# Este es un cachorro sin dueño y la raza DOBERMAN y es de color PURPURA y su nombre es FIRULAIS

# %%
#calculsr para un rectangulo su area su perimetro y su diagonal
class Rectangulo():
  def __init__(self,p_alto,p_ancho):
    self.alto = p_alto
    self.ancho = p_ancho
  def m_perimetro(self):
    perimetro=(self.alto*2)+(self.ancho*2)
    return perimetro
  def m_area(self):
    area=self.alto*self.ancho
    return area

p_alto=int(input("Alto del rectangulo : "))
p_ancho=int(input("Ancho del rectangulo : "))

obj_rect2=Rectangulo(p_alto,p_ancho)

print("El area es : ",+obj_rect2.m_area())
print("El perimetro es : ",+obj_rect2.m_perimetro())
# Out:
# Alto del rectangulo : 10
# Ancho del rectangulo : 15
# El area es :  150
# El perimetro es :  50
