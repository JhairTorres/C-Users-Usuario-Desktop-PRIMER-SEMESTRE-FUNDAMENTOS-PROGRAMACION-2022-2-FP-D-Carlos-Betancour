# %%
n=int(input("Ingrese la cantidad de notas a promediar:" ))
suma=0
i=1
while(i <= n):
  print("Ingrese la nota del estudiante:", i )
  nota=float(input())
  suma=suma+nota
  i+=1
prom=suma/n
print('El promedio es',prom)
# Out:
# Ingrese la cantidad de notas a promediar:35
# Ingrese la nota numero: 1
# 4
# Ingrese la nota numero: 2
# 5
# Ingrese la nota numero: 3
# 6
# Ingrese la nota numero: 4
# 7
# Ingrese la nota numero: 5
# 3
# Ingrese la nota numero: 6
# 5
# Ingrese la nota numero: 7
# 2
# Ingrese la nota numero: 8
# 6
# Ingrese la nota numero: 9
# 4
# Ingrese la nota numero: 10
# 7
# Ingrese la nota numero: 11
# 9
# Ingrese la nota numero: 12
# 3
# Ingrese la nota numero: 13
# 4
# Ingrese la nota numero: 14
# 5
# Ingrese la nota numero: 15
# 3
# Ingrese la nota numero: 16
# 5
# Ingrese la nota numero: 17
# 6
# Ingrese la nota numero: 18
# 4.5
# Ingrese la nota numero: 19
# 6
# Ingrese la nota numero: 20
# 4
# Ingrese la nota numero: 21
# 5
# Ingrese la nota numero: 22
# 8
# Ingrese la nota numero: 23
# 9
# Ingrese la nota numero: 24
# 7
# Ingrese la nota numero: 25
# 6
# Ingrese la nota numero: 26
# 9
# Ingrese la nota numero: 27
# 7
# Ingrese la nota numero: 28
# 8
# Ingrese la nota numero: 29
# 4
# Ingrese la nota numero: 30
# 6
# Ingrese la nota numero: 31
# 3
# Ingrese la nota numero: 32
# 7
# Ingrese la nota numero: 33
# 8
# Ingrese la nota numero: 34
# 9
# Ingrese la nota numero: 35
# 10
# El promedio es 5.8428571428571425
